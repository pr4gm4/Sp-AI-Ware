# %% [markdown]
# #### Importing Modules

# %%
import pandas as pd
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Loading Dataset

# %%
size = 5000
dataset = pd.read_csv("../../Datasets/"+str(size)+"dataset.csv")
dataset
# Out:
#                                                     sha  is_malicious  \
# 0     d2dbaa97b1977b643f2a4fe99843431cb370de5c254881...             0
# 1     20479d17df1313d1b31909c5a169b378f4a55948023f86...             0
# 2     95ea1b97a64a8ed5e5d9abb692c858c02f5ba384cadc87...             0
# 3     909a25ce0eab1f7decb892a03bc9930333a12fb011269e...             0
# 4     648171f8d5d24b8d32de89250d89dba430e38d634330ab...             1
# ...                                                 ...           ...
# 4995  485fb3ac9d471bb615c2fc7890b84cb1107985274ecfde...             0
# 4996  6788807914ee90bc00ac6f6e9e94b049f91f9af372e14f...             1
# 4997  14133fe8f77245826e1365a33382ee120dc60d16d8bd13...             0
# 4998  bbc603ceef733139e464e9bf20bc51a56f37ec2142c1b0...             1
# 4999  9574b87b27fd2a1190ba04dc1ced0ad45d379aeac888c2...             0
#
#              0         1         2         3         4         5         6  \
# ...

# %% [markdown]
# #### Normalization

# %%
mmscaler = MinMaxScaler()
dataset.iloc[:,2:] = mmscaler.fit_transform(dataset.iloc[:,2:])
dataset
# Out:
#                                                     sha  is_malicious  \
# 0     d2dbaa97b1977b643f2a4fe99843431cb370de5c254881...             0
# 1     20479d17df1313d1b31909c5a169b378f4a55948023f86...             0
# 2     95ea1b97a64a8ed5e5d9abb692c858c02f5ba384cadc87...             0
# 3     909a25ce0eab1f7decb892a03bc9930333a12fb011269e...             0
# 4     648171f8d5d24b8d32de89250d89dba430e38d634330ab...             1
# ...                                                 ...           ...
# 4995  485fb3ac9d471bb615c2fc7890b84cb1107985274ecfde...             0
# 4996  6788807914ee90bc00ac6f6e9e94b049f91f9af372e14f...             1
# 4997  14133fe8f77245826e1365a33382ee120dc60d16d8bd13...             0
# 4998  bbc603ceef733139e464e9bf20bc51a56f37ec2142c1b0...             1
# 4999  9574b87b27fd2a1190ba04dc1ced0ad45d379aeac888c2...             0
#
#              0         1         2         3         4         5         6  \
# ...

# %% [markdown]
# #### Standardization

# %%
scaler = StandardScaler()
dataset.iloc[:,2:] = scaler.fit_transform(dataset.iloc[:,2:])
dataset
# Out:
#                                                     sha  is_malicious  \
# 0     d2dbaa97b1977b643f2a4fe99843431cb370de5c254881...             0
# 1     20479d17df1313d1b31909c5a169b378f4a55948023f86...             0
# 2     95ea1b97a64a8ed5e5d9abb692c858c02f5ba384cadc87...             0
# 3     909a25ce0eab1f7decb892a03bc9930333a12fb011269e...             0
# 4     648171f8d5d24b8d32de89250d89dba430e38d634330ab...             1
# ...                                                 ...           ...
# 4995  485fb3ac9d471bb615c2fc7890b84cb1107985274ecfde...             0
# 4996  6788807914ee90bc00ac6f6e9e94b049f91f9af372e14f...             1
# 4997  14133fe8f77245826e1365a33382ee120dc60d16d8bd13...             0
# 4998  bbc603ceef733139e464e9bf20bc51a56f37ec2142c1b0...             1
# 4999  9574b87b27fd2a1190ba04dc1ced0ad45d379aeac888c2...             0
#
#              0         1         2         3         4         5         6  \
# ...

# %% [markdown]
# #### Feature Filtering

# %%
correlation = dataset.corr("spearman")
correlation
# Out:
#               is_malicious         0         1         2         3         4  \
# is_malicious      1.000000 -0.055813 -0.359197 -0.297338 -0.299463 -0.235015
# 0                -0.055813  1.000000  0.472726  0.204253  0.095557  0.230746
# 1                -0.359197  0.472726  1.000000  0.762213  0.679368  0.727585
# 2                -0.297338  0.204253  0.762213  1.000000  0.787950  0.808804
# 3                -0.299463  0.095557  0.679368  0.787950  1.000000  0.724968
# ...                    ...       ...       ...       ...       ...       ...
# 2376             -0.323130 -0.007983  0.160181  0.102452  0.103309  0.063827
# 2377             -0.214971 -0.025128  0.090108  0.101021  0.088856  0.071363
# 2378             -0.215139 -0.023945  0.091988  0.101414  0.091035  0.074587
# 2379             -0.209171  0.276758  0.364873  0.300255  0.205370  0.191900
# 2380             -0.239330  0.299174  0.396838  0.334057  0.231246  0.221715
#
# ...

# %%
best_features = correlation.iloc[0]
best_features = best_features.abs()
best_features = best_features.sort_values(ascending=False)
best_features = best_features[0:26]
best_index = best_features.index
best_index
# Out:
# Index(['is_malicious', '658', '2360', '2359', '613', '930', '637', '623',
#        '2363', '2364', '618', '622', '642', '698', '2375', '683', '679', '641',
#        '578', '798', '748', '640', '626', '834', '734', '32'],
#       dtype='object')

# %%
ref_dataset = dataset.loc[:,best_index]
ref_dataset["sha"] = dataset.loc[:,"sha"]
ref_dataset
# Out:
#       is_malicious       658      2360      2359       613       930  \
# 0                0  0.809282 -0.153843 -0.368721 -0.111911 -0.437024
# 1                0 -0.629186 -0.153843 -0.368721 -0.103857 -0.437024
# 2                0 -0.629186  0.293131  0.227423 -0.103857 -0.437024
# 3                0  0.809282 -0.153843 -0.368721 -0.111911 -0.437024
# 4                1  0.809282 -0.153843 -0.368721 -0.111911 -0.437024
# ...            ...       ...       ...       ...       ...       ...
# 4995             0 -2.067653 -0.153521  2.079474  0.242431 -0.437024
# 4996             1  0.809282 -0.153843 -0.368721 -0.111911 -0.437024
# 4997             0 -0.629186  3.913876  0.268265  0.024994 -0.437024
# 4998             1  0.809282 -0.153843 -0.368721 -0.111911  1.172047
# 4999             0 -0.629186 -0.141000  1.177011  0.113579 -0.437024
#
#            637       623      2363      2364  ...       641       578  \
# ...

# %% [markdown]
# #### Export Filtered Dataset

# %%
file_path = "../../Datasets/"+str(size)+"dataset.csv"
ref_dataset.to_csv(file_path,index=False)
